# %%
import pandas as pd

# %%
df = pd.read_excel('../patentes/desenho.xlsx',sheet_name = 'Sheet1')

# %%
df.columns
# Out:
# Index(['id_lattes', 'respondeu', 'inct', 'grupo_tematico', 'membro_status',
#        'nome_completo', 'id_patente', 'titulo_marca', 'ano_desenvolvimento',
#        'pais', 'flag_relevancia', 'titulo_ingles', 'flag_potencial_inovacao',
#        'finalidade', 'instituicao_financiadora', 'finalidade_ingles',
#        'tipo_patente', 'titulo_patente_reg', 'data_pedido_de_deposito',
#        'data_pedido_de_exame', 'data_de_concessao',
#        'instituicao_deposito_registro', 'numero_deposito_pct',
#        'formato_data_deposito_pct', 'data_deposito_pct', 'nome_titular',
#        'nome_depositante', 'nome_grande_area_do_conhecimento',
#        'nome_da_area_do_conhecimento', 'nome_da_sub_area_do_conhecimento',
#        'nome_da_especialidade', 'nome_completo_autores',
#        'nome_citacao_autores', 'ordem_autoria_autores', 'id_autores'],
#       dtype='object')

# %%
len(df)
# Out:
# 76

# %%
df.head()
# Out:
#          id_lattes  respondeu  \
# 1   77858881652243      False
# 2  624746940489201      False
# 3  847897516772421      False
# 4  905407015458080      False
# 5  905407015458080      False
#
#                                                 inct  \
# 1   INCT de Arqueologia, Paleontologia  e Ambient...
# 2                 INCT em Refrigeração e Termofísica
# 3  INCT de Energias Renováveis e Eficiência Energ...
# 4         INCT em Fotônica para Comunicações Ópticas
# 5         INCT em Fotônica para Comunicações Ópticas
#
#              grupo_tematico  membro_status  \
# 1  Ecologia e Meio Ambiente            NaN
# 2           Engenharia e TI            NaN
# 3                   Energia            NaN
# 4           Engenharia e TI            NaN
# 5           Engenharia e TI            NaN
#
#                                nome_completo id_patente  \
# 1                    Sandra de Brito Barreto  910191506
# 2  Luciana Wasnievski da Silva de Luca Ramos  D598996S1
# ...
